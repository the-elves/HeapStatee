# %%
import os
print(os.getcwd())
# Out:
# /home/ajinkya

# %%
import angr
import os
b = angr.Project('Guided_HLM/HeapStatee/AngrState/TestCases/UAF')
# Out:
# WARNING | 2020-06-19 01:13:50,685 | cle.loader | The main binary is a position-independent executable. It is being loaded with a base address of 0x400000.

# %%
cfg = b.analyses.CFG()
# Out:
# WARNING | 2020-06-19 01:14:03,926 | angr.analyses.cfg.cfg_fast | "auto_load_libs" is enabled. With libraries loaded in project, CFGFast will cover libraries, which may take significantly more time than expected. You may reload the binary with "auto_load_libs" disabled, or specify "regions" to limit the scope of CFG recovery.
# WARNING | 2020-06-19 01:14:05,433 | angr.state_plugins.symbolic_memory | Filling memory at 0x7ffffffffff0004 with 4 unconstrained bytes referenced from 0x80fcf8 (open+0xb8 in libc.so.6 (0x10fcf8))
# WARNING | 2020-06-19 01:14:05,434 | angr.state_plugins.symbolic_memory | Filling memory at 0x7fffffffffefff8 with 8 unconstrained bytes referenced from 0x80fcfc (open+0xbc in libc.so.6 (0x10fcfc))
# WARNING | 2020-06-19 01:14:05,436 | angr.state_plugins.symbolic_memory | Filling memory at 0x7ffffffffff0000 with 4 unconstrained bytes referenced from 0x80fd03 (open+0xc3 in libc.so.6 (0x10fd03))
# ...

# %%
mstate = b.factory.entry_state(addr=b.loader.find_symbol('main').rebased_addr)
print('malloc_address: %d' %(b.loader.find_symbol('malloc').rebased_addr))
m = b.factory.simgr(mstate)
while(len(m.active)==1):
    m.step()
print(m.stashes)
# Out:
# WARNING | 2020-06-19 01:16:49,673 | angr.state_plugins.symbolic_memory | Filling register rdi with 8 unconstrained bytes referenced from 0x400692 (main+0x8 in UAF (0x692))
# WARNING | 2020-06-19 01:16:49,676 | angr.state_plugins.symbolic_memory | Filling register rsi with 8 unconstrained bytes referenced from 0x400695 (main+0xb in UAF (0x695))
# malloc_address: 7958640
# defaultdict(<class 'list'>, {'active': [<SimState @ 0x40068a>], 'stashed': [], 'pruned': [], 'unsat': [], 'errored': [], 'deadended': [], 'unconstrained': []})
# defaultdict(<class 'list'>, {'active': [<SimState @ 0x400560>], 'stashed': [], 'pruned': [], 'unsat': [], 'errored': [], 'deadended': [], 'unconstrained': []})
# defaultdict(<class 'list'>, {'active': [<SimState @ 0x797070>], 'stashed': [], 'pruned': [], 'unsat': [], 'errored': [], 'deadended': [], 'unconstrained': []})
# ...
